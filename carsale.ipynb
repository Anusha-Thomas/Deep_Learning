# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("car.csv")
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.shape
# Out:
# (4340, 8)

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (3577, 8)

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  3577.000000   3.577000e+03    3577.000000
# mean   2012.962538   4.739125e+05   69250.545709
# std       4.251759   5.093018e+05   47579.940016
# min    1992.000000   2.000000e+04       1.000000
# 25%    2010.000000   2.000000e+05   36000.000000
# 50%    2013.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df_num = df.select_dtypes(include=[np.number])

# %%
df_num.corr
# Out:
# <bound method DataFrame.corr of       year  selling_price  km_driven
# 0     2007          60000      70000
# 1     2007         135000      50000
# 2     2012         600000     100000
# 3     2017         250000      46000
# 4     2014         450000     141000
# ...    ...            ...        ...
# 4335  2014         409999      80000
# 4336  2014         409999      80000
# 4337  2009         110000      83000
# 4338  2016         865000      90000
# 4339  2016         225000      40000
#
# [3577 rows x 3 columns]>

# %%
sns.heatmap(df_num.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
sns.histplot(df_num['selling_price'], bins=20)
# Out:
# <Axes: xlabel='selling_price', ylabel='Count'>

# %%
sns.histplot(df_num['km_driven'], bins=20)
# Out:
# <Axes: xlabel='km_driven', ylabel='Count'>

# %%
sns.scatterplot(x='km_driven', y='selling_price', data=df_num)
# Out:
# <Axes: xlabel='km_driven', ylabel='selling_price'>

# %%
sns.scatterplot(x="year" ,y='km_driven', data=df_num)
# Out:
# <Axes: xlabel='year', ylabel='km_driven'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='name', y='selling_price', data=df.head(8))
# Out:
# <Axes: xlabel='name', ylabel='selling_price'>

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df = df.to_csv("carsales.csv", index=False)
